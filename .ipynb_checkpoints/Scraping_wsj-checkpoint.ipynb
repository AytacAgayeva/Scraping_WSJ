# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import date,datetime
import os, sys
import selenium

# %%
#dir(selenium)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'common',
#  'types',
#  'webdriver']

# %%
from selenium import webdriver
# from webdriver_manager.chrome import ChromeDriverManager
# service = ChromeService(executable_path=ChromeDriverManager().install())

driver = webdriver.Chrome(executable_path=r'C:\Users\Aytac Agayev\Downloads\chromedriver_win32\chromedriver.exe')
driver.get('https://www.wsj.com/wsjsitemaps/wsj_google_news.xml')
driver
# Out:
# C:\Users\Aytac Agayev\AppData\Local\Temp\ipykernel_3924\4294346460.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\Aytac Agayev\Downloads\chromedriver_win32\chromedriver.exe')
# <selenium.webdriver.chrome.webdriver.WebDriver (session="6d9a90a5a8b8d6a043e1e70c04953458")>

# %%
driver.page_source
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head><style id="xml-viewer-style">/* Copyright 2014 The Chromium Authors\n * Use of this source code is governed by a BSD-style license that can be\n * found in the LICENSE file.\n */\n\n:root {\n  color-scheme: light dark;\n}\n\ndiv.header {\n    border-bottom: 2px solid black;\n    padding-bottom: 5px;\n    margin: 10px;\n}\n\n@media (prefers-color-scheme: dark) {\n  div.header {\n    border-bottom: 2px solid white;\n  }\n}\n\ndiv.folder &gt; div.hidden {\n    display:none;\n}\n\ndiv.folder &gt; span.hidden {\n    display:none;\n}\n\n.pretty-print {\n    margin-top: 1em;\n    margin-left: 20px;\n    font-family: monospace;\n    font-size: 13px;\n}\n\n#webkit-xml-viewer-source-xml {\n    display: none;\n}\n\n.opened {\n    margin-left: 1em;\n}\n\n.comment {\n    white-space: pre;\n}\n\n.folder-button {\n    user-select: none;\n    cursor: pointer;\n    display: inline-block;\n    margin-left: -10px;\n    width: 10px;\n    background-repeat: no-repeat;\n    background-position: left top;\n    vertical-align: bottom;\n}\n\n.fold {\n    background: url("data:image/svg+xml,&lt;svg xmlns=\'http://www.w3.org/2000/svg\' fill=\'%23909090\' width=\'10\' height=\'10\'&gt;&lt;path d=\'M0 0 L8 0 L4 7 Z\'/&gt;&lt;/svg&gt;");\n    height: 10px;\n}\n\n.open {\n    background: url("data:image/svg+xml,&lt;svg xmlns=\'http://www.w3.org/2000/svg\' fill=\'%23909090\' width=\'10\' height=\'10\'&gt;&lt;path d=\'M0 0 L0 8 L7 4 Z\'/&gt;&lt;/svg&gt;");\n    height: 10px;\n}\n</style></head><body><div id="webkit-xml-viewer-source-xml"><urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:news="http://www.google.com/schemas/sitemap-news/0.9" xmlns:image="http://www.google.com/schemas/sitemap-image/1.1">\n    <url>\n        <loc>https://www.wsj.com/livecoverage/federal-reserve-meeting-interest-rate-hike-expected-may-2023</loc>\n        <news:news>\n            <news:publication>\n                <news:name>The Wall Street Journal</news:name>\n                <news:language>en</news:language>\n            </news:publication>\n            <news:publication_date>2023-05-03T13:32:03+00:00</news:publication_date>\n            <news:title>Fed Meeting Today Live: What to Watch Ahead of Likely on Interest Rate Hike, Powell\'s Speech</news:title>\n        </news:news>\n        <image:image>\n            <image:loc>https://images.wsj.net/im-773594/social</image:loc>\n        </image:image>\n    </url>\n    <url>\n        <loc>https://www.wsj.com/livecoverage/stock-market-today-dow-jones-05-02-2023</loc>\n        <news:news>\n            <news:publication>\n                <news:name>The Wall Street Journal</news:name>\n                <news:language>en</news:language>\n            </news:publication>\n            <news:publication_date>2023-05-02T21:58:53+00:00</news:publication_date>\n            <news:title>Stock Market Today: Dow Closes Down More Than 300 Points as Fed Day Looms</news:title>\n        </news:news>\n        <image:image>\n            <image:loc>https://images.wsj.net/im-589547/social</image:loc>\n        </image:image>\n    </url>\n    <url>\n        <loc>https://www.wsj.com/livecoverage/stock-market-today-dow-jones-05-01-2023</loc>\n        <news:news>\n            <news:publication>\n                <news:name>The Wall Street Journal</news:name>\n                <news:language>en</news:language>\n            </news:publication>\n            <news:publication_date>2023-05-01T22:06:42+00:00</news:publication_date>\n            <news:title>Stock Market News, May 1, 2023: Stocks Close Slightly Lower After First Republic Bank Sold to JPMorgan</news:title>\n        </news:news>\n        <image:image>\n            <image:loc>https://images.wsj.net/im-589547/social</image:loc>\n        </image:image>\n    </url>\n    <url>\n        <loc>https://www.wsj.com/articles/samsung-is-a-case-study-in-how-manufacturers-leave-china-5dcb2dcf</loc>\n        <news:news>\n            <news:publication>\n       ...

# %%
soup = BeautifulSoup(driver.page_source, 'html')
urls = soup.find_all("url")
today=date.today()
now = datetime.now()
current_time = now.strftime("%H_%M")
data = []
for url in urls:
    loc = url.loc.text
    title = url.find("news:title").text
    language = url.find("news:language").text
    publication_date = url.find("news:publication_date").text[:10]
    publication_time = url.find("news:publication_date").text[11:19]
    image_loc_tag = url.find("image:loc")
    keywords_tag=url.find("news:keywords")
    if image_loc_tag and keywords_tag  is not None:
        image_loc = image_loc_tag.text
        keywords=keywords_tag.text
    row_data = {
        "URL": loc,
        "Title": title,
        "Language":language,
        "Publication Date": publication_date,
        "Publication Time": publication_time,
        "Image URL": image_loc,
        }
    data.append(row_data)    
df = pd.DataFrame(data)
path="./json"
df.to_json(os.path.join(path,f'sitemap_wsj_news__{today}_{current_time}.json'))
df
# Out:
#                                                    URL  \
# 0    https://www.wsj.com/livecoverage/federal-reser...
# 1    https://www.wsj.com/livecoverage/stock-market-...
# 2    https://www.wsj.com/livecoverage/stock-market-...
# 3    https://www.wsj.com/articles/samsung-is-a-case...
# 4    https://www.wsj.com/articles/youre-about-to-pa...
# ..                                                 ...
# 281  https://www.wsj.com/livecoverage/stock-market-...
# 282  https://www.wsj.com/livecoverage/stock-market-...
# 283  https://www.wsj.com/livecoverage/stock-market-...
# 284  https://www.wsj.com/livecoverage/stock-market-...
# 285  https://www.wsj.com/livecoverage/stock-market-...
#
#                                                  Title Language  \
# 0    Fed Meeting Today Live: What to Watch Ahead of...       en
# 1    Stock Market Today: Dow Closes Down More Than ...       en
# 2    Stock Market News, May 1, 2023: Stocks Close S...       en
# 3    Samsung is a Case Study in How Manufacturers L...       en
# 4    You’re About to Pay $300,000 for College. What...       en
# ..                                                 ...      ...
# 281  Rate Cuts Look Less Likely After Hot Manufactu...       en
# 282              What Happens to First Republic Stock?       en
# 283  JPMorgan Won’t Be Keeping First Republic’s Nam...       en
# 284  Will First Republic’s Failure and the Fed Meet...       en
# 285   This Isn't the First First Republic Bank to Fall       en
#
#     Publication Date Publication Time  \
# 0         2023-05-03         13:32:03
# 1         2023-05-02         21:58:53
# 2         2023-05-01         22:06:42
# 3         2023-05-03         13:17:00
# 4         2023-05-03         13:16:00
# ..               ...              ...
# 281       2023-05-01         15:00:00
# 282       2023-05-01         13:46:30
# 283       2023-05-01         14:45:01
# 284       2023-05-01         14:30:00
# 285       2023-05-01         14:00:00
#
#                                              Image URL
# 0              https://images.wsj.net/im-773082/social
# 1              https://images.wsj.net/im-773082/social
# 2              https://images.wsj.net/im-773082/social
# 3    https://images.wsj.net/im-773971?width=1280&si...
# 4    https://images.wsj.net/im-773650?size=0.710716...
# ..                                                 ...
# 281            https://images.wsj.net/im-772435/social
# 282            https://images.wsj.net/im-772435/social
# 283            https://images.wsj.net/im-773082/social
# 284            https://images.wsj.net/im-773082/social
# 285            https://images.wsj.net/im-773082/social
#
# [286 rows x 6 columns]

# %%
files = [f for f in os.listdir(path) if f.endswith(".json")]
files.sort()
last_2_files=files[-2:]
if len(last_2_files)==2:
    data_new=pd.read_json(f'./json/{last_2_files[1]}')
    data_old=pd.read_json(f'./json/{last_2_files[0]}')
    news_count = pd.DataFrame({"Time": [last_2_files[1][-10:-5]], "Count": [data_new.shape[0]]})
    old = set(data_old['Title'])
    new = set(data_new['Title'])
    dif_old = old.difference(new)
    dif_new = new.difference(old)
    inter = old.intersection(new)
    all_news = pd.DataFrame({"Time": [f'{last_2_files[0][-10:-5]} - {last_2_files[1][-10:-5]}'], 
                          "NEW": [len(dif_new)], 
                          "SAME": [len(inter)], 
                          "EXCLUDED": [len(dif_old)]})
    all_news.to_csv(f'./all_news/sitemap_wsj_news_{today}__{current_time}.csv',index=False)
    news_count.to_csv(f'./news_count/sitemap_wsj_news_{today}__{current_time}.csv',index=False)
    
    files_news = [f for f in os.listdir("./all_news") if f.endswith(".csv")]
    files_news.sort()
    file_path = os.path.join("./all_news", files_news[0])
    data_all = pd.read_csv(file_path)
    data_all=pd.concat([data_all,all_news],axis=0)
    data_all.to_csv(file_path,index=False)
    
    count_news = [f for f in os.listdir("./news_count") if f.endswith(".csv")]
    count_news.sort()
    count_path = os.path.join("./news_count", count_news[0])
    count_all = pd.read_csv(count_path)
    count_all=pd.concat([count_all,news_count],axis=0)
    count_all.to_csv(count_path,index=False)
    
else:
    data_old=pd.read_json(f'./json/{last_2_files[0]}')
    news_count = pd.DataFrame({"Time": [last_2_files[0][-10:-5]], "Count": [data_old.shape[0]]})
    all_news_ = pd.DataFrame({"Time": [f'{last_2_files[0][-10:-5]}'], 
                          "NEW": [data_old.shape[0]], 
                          "SAME": [0], 
                          "EXCLUDED": [0]})
    all_news_.to_csv(f'./all_news/all_time_news.csv',index=False)
    news_count.to_csv(f'./news_count/all_time_news_count.csv',index=False)
